# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://github.com/AI-Maker-Space/LLM-Dev-101/assets/37101144/d1343317-fa2f-41e1-8af1-1dbb18399719"
#      width="200px"
#      height="auto"/>
# </p>
#
# <h1 align="center" id="heading">OpenAI Agents SDK - AIM</h1>
#
# In this notebook, we'll go over some of the key features of the OpenAI Agents SDK - as explored through a notebook-ified version of their [Research Bot](https://github.com/openai/openai-agents-python/tree/main/examples/research_bot).

# %%
### You don't need to run this cell if you're running this notebook locally. 

#!pip install -qU openai-agents

# %% [markdown]
# API Key:

# %%
import os 
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# Nest Async:

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Agents
#
# As may be expected, the primary thing we'll do in the Agents SDK is construct Agents!
#
# Agents are constructed with a few basic properties:
#
# - A prompt, which OpenAI is using the language "instruction" for, that determines the behaviour or goal of the Agent
# - A model, the "brain" of the Agent
#
# They also typically include an additional property:
#
# - Tool(s) that equip the Agent with things it can use to get stuff done

# %% [markdown]
# ### Task 1: Create Planner Agent
#
# Let's start by creating our "Planner Agent" - which will come up with the initial set of search terms that should answer a query provided by the user.

# %%
from pydantic import BaseModel
from agents import Agent

PLANNER_PROMPT = (
    "You are a helpful research assistant. Given a query, come up with a set of web searches to perform" 
    "to best answer the query. Output between 5 and 20 terms to query for."
)

# %% [markdown]
# Next, we'll define the data models that our Planner Agent will use to structure its output. We'll create:
#
# 1. `WebSearchItem` - A model for individual search items, containing the search query and reasoning
# 2. `WebSearchPlan` - A container model that holds a list of search items
#
# These Pydantic models will help ensure our agent returns structured data that we can easily process.

# %%
class WebSearchItem(BaseModel):
    reason: str
    "Your reasoning for why this search is important to the query."

    query: str
    "The search term to use for the web search."

class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem]
    """A list of web searches to perform to best answer the query."""

# %% [markdown]
# Now we'll create our Planner Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `PLANNER_PROMPT` and will output structured data in the form of our WebSearchPlan model. We're using the GPT-4o model for this agent to ensure high-quality search term generation.
#
# > NOTE: When we provide an `output_type` - the model will return a [structured response](https://platform.openai.com/docs/guides/structured-outputs?api-mode=responses).

# %%
planner_agent = Agent(
    name="PlannerAgent",
    instructions=PLANNER_PROMPT,
    model="gpt-4.1",
    output_type=WebSearchPlan,
)

# %% [markdown]
# #### ❓Question #1:
#
# Why is it important to provide a structured response template? (As in: Why are structured outputs helpful/preferred in Agentic workflows?)

# %% [markdown]
# ##### Answer:
# Structured outputs are crucial because they:
# - Ensure Consistency: Predictable response formats
# - Enable Automation: Reliable parsing between agents
# - Reduce Errors: Minimize validation failures
# - Facilitate Integration: Seamless agent chaining
# - Improve Reliability: Type safety for interactions

# %% [markdown]
# ### Task 2: Create Search Agent
#
# Now we'll create our Search Agent, which will be responsible for executing web searches based on the terms generated by the Planner Agent. This agent will take each search query, perform a web search using the `WebSearchTool`, and then summarize the results in a concise format.
#
# > NOTE: We are using the `WebSearchTool`, a hosted tool that can be used as part of an `OpenAIResponsesModel` as outlined in the [documentation](https://openai.github.io/openai-agents-python/tools/). This is based on the tools available through OpenAI's new [Responses API](https://openai.com/index/new-tools-for-building-agents/).
#
# The `SEARCH_PROMPT` below instructs the agent to create brief, focused summaries of search results. These summaries are designed to be 2-3 paragraphs, under 300 words, and capture only the essential information without unnecessary details. The goal is to provide the Writer Agent with clear, distilled information that can be efficiently synthesized into the final report.

# %%
SEARCH_PROMPT = (
    "You are a research assistant. Given a search term, you search the web for that term and"
    "produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300"
    "words. Capture the main points. Write succinctly, no need to have complete sentences or good"
    "grammar. This will be consumed by someone synthesizing a report, so its vital you capture the"
    "essence and ignore any fluff. Do not include any additional commentary other than the summary"
    "itself."
)

# %% [markdown]
# Now we'll create our Search Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `SEARCH_PROMPT` and will utilize the `WebSearchTool` to perform web searches. We're configuring it with `tool_choice="required"` to ensure it always uses the search tool when processing requests.
#
# > NOTE: We can, as demonstrated, indicate how we want our model to use tools. You can read more about that at the bottom of the page [here](https://openai.github.io/openai-agents-python/agents/)

# %%
from agents import WebSearchTool
from agents.model_settings import ModelSettings

search_agent = Agent(
    name="Search agent",
    instructions=SEARCH_PROMPT,
    tools=[WebSearchTool()],
    model_settings=ModelSettings(tool_choice="required"),
)

# %% [markdown]
# #### ❓ Question #2:
#
# What other tools are supported in OpenAI's Responses API?

# %% [markdown]
# ##### Answer:
# OpenAI Responses API supports:
# - WebSearchTool: Web searching capabilities
# - FileSearchTool: Search uploaded files
# - ComputerTool: Desktop interaction
# - CodeInterpreter: Python execution
# - Function Tools: Custom definitions

# %% [markdown]
# ### Task 3: Create Writer Agent
#
# Finally, we'll create our Writer Agent, which will synthesize all the research findings into a comprehensive report. This agent takes the original query and the research summaries from the Search Agent, then produces a structured report with follow-up questions.
#
# The Writer Agent will:
# 1. Create an outline for the report structure
# 2. Generate a detailed markdown report (5-10 pages)
# 3. Provide follow-up questions for further research
#
# We'll define the prompt for this agent in the next cell. This prompt will instruct the Writer Agent on how to synthesize research findings into a comprehensive report with follow-up questions.

# %%
WRITER_PROMPT = (
    "You are an expert financial analyst and stock researcher tasked with writing comprehensive "
    "research reports to identify specific hidden gem stocks. Focus on fundamental analysis, "
    "technical indicators, market positioning, and growth potential.\n\n"
    "Structure your analysis with the following sections:\n\n"
    "## 1. Executive Summary\n"
    "- Key findings and investment thesis\n"
    "- Overall market opportunity\n\n"
    "## 2. Research Methodology\n"
    "- Specific criteria used for stock selection\n"
    "- Screening process and data sources\n\n"
    "## 3. Stock Analysis\n"
    "For each identified stock, provide:\n"
    "- **Ticker Symbol** and Company Name\n"
    "- **Current Price** and Market Cap\n"
    "- **Key Metrics** (P/E, P/B, Debt/Equity, etc.)\n"
    "- **Investment Thesis** (why it's a hidden gem)\n"
    "- **Risk Factors** and Mitigation\n"
    "- **Price Targets** and Entry/Exit Points\n\n"
    "## 4. Comparative Analysis\n"
    "Create a comparison table with:\n"
    "| Ticker | Price | P/E | P/B | Growth | Risk | Rating |\n"
    "|--------|-------|-----|-----|--------|------|--------|\n\n"
    "## 5. Investment Strategy\n"
    "- Portfolio allocation recommendations\n"
    "- Entry timing and position sizing\n"
    "- Risk management guidelines\n\n"
    "## 6. Market Outlook\n"
    "- Sector trends and catalysts\n"
    "- Economic factors affecting these stocks\n\n"
    "## 7. Risk Assessment\n"
    "- Market risks and company-specific risks\n"
    "- Mitigation strategies\n\n"
    "Write in clear, professional language with proper markdown formatting including:\n"
    "- **Bold headers** for sections\n"
    "- *Italic text* for emphasis\n"
    "- Bullet points and numbered lists\n"
    "- Tables for comparative data\n"
    "- Code blocks for technical metrics\n"
    "- Blockquotes for key insights\n\n"
    "The final output should be comprehensive and detailed, aiming for 6-10 pages of content "
    "with at least 2000 words. Include specific stock names, ticker symbols, and actionable "
    "investment recommendations.\n\n"
    "For the follow-up questions, provide exactly 5 unique research questions that would "
    "help extend this analysis. Focus on additional screening criteria, sector analysis, "
    "risk factors, and emerging market opportunities."
)

# %% [markdown]
# #### 🏗️ Activity #1:
#
# This prompt is quite generic - modify this prompt to produce a report that is more personalized to either your personal preference, or more appropriate for a specific use case (eg. law domain research)

# %% [markdown]
# ##### Activity 1: Stock research
#
# This prompt will create detailed stock research reports focused on finding hidden investment opportunities!

# %% [markdown]
# Now we'll create our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will synthesize all the research findings into a comprehensive report. We're configuring it with the `ReportData` output type to structure the response with a short summary, markdown report, and follow-up questions.

# %%
class ReportData(BaseModel):
    short_summary: str
    """A short 2-3 sentence summary of the findings."""

    markdown_report: str
    """The final report"""

    follow_up_questions: list[str]
    """Suggested topics to research further"""

# %% [markdown]
# Now we'll define our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will take the original query and research summaries, then synthesize them into a comprehensive report with follow-up questions. We've defined a custom output type called `ReportData` that structures the response with a short summary, markdown report, and follow-up questions.

# %%
writer_agent = Agent(
    name="WriterAgent",
    instructions=WRITER_PROMPT,
    model="o3-mini",
    output_type=ReportData,
)

# %% [markdown]
# #### ❓ Question #3:
#
# Why are we electing to use a reasoning model for writing our report?

# %% [markdown]
# ##### Answer:
# We use a reasoning model (o3-mini) for the Writer Agent because:
# - Complex Synthesis: Combines multiple research sources coherently
# - Logical Structure: Creates well-organized reports with clear flow
# - Critical Analysis: Evaluates and weighs different information sources
# - Depth of Reasoning: Provides deeper insights beyond surface-level summaries
# - Quality Control: Ensures higher-quality output through reasoning process

# %% [markdown]
# ## Task 4: Create Utility Classes
#
# We'll define utility classes to help with displaying progress and managing the research workflow. The Printer class below will provide real-time updates on the research process.

# %% [markdown]
# The Printer class provides real-time progress updates during the research process. It uses Rich's Live display to show dynamic content with spinners for in-progress items and checkmarks for completed tasks. The class maintains a dictionary of items with their completion status and can selectively hide checkmarks for specific items. This creates a clean, interactive console experience that keeps the user informed about the current state of the research workflow.

# %%
from typing import Any

from rich.console import Console, Group
from rich.live import Live
from rich.spinner import Spinner

class Printer:
    def __init__(self, console: Console):
        self.live = Live(console=console)
        self.items: dict[str, tuple[str, bool]] = {}
        self.hide_done_ids: set[str] = set()
        self.live.start()

    def end(self) -> None:
        self.live.stop()

    def hide_done_checkmark(self, item_id: str) -> None:
        self.hide_done_ids.add(item_id)

    def update_item(
        self, item_id: str, content: str, is_done: bool = False, hide_checkmark: bool = False
    ) -> None:
        self.items[item_id] = (content, is_done)
        if hide_checkmark:
            self.hide_done_ids.add(item_id)
        self.flush()

    def mark_item_done(self, item_id: str) -> None:
        self.items[item_id] = (self.items[item_id][0], True)
        self.flush()

    def flush(self) -> None:
        renderables: list[Any] = []
        for item_id, (content, is_done) in self.items.items():
            if is_done:
                prefix = "✅ " if item_id not in self.hide_done_ids else ""
                renderables.append(prefix + content)
            else:
                renderables.append(Spinner("dots", text=content))
        self.live.update(Group(*renderables))

# %% [markdown]
# Let's create a ResearchManager class that will orchestrate the research process. This class will:
# 1. Plan searches based on the query
# 2. Perform those searches to gather information
# 3. Write a comprehensive report based on the gathered information
# 4. Display progress using our Printer class

# %%
from __future__ import annotations

import asyncio
import time

from agents import Runner, custom_span, gen_trace_id, trace

class ResearchManager:
    def __init__(self):
        self.console = Console()
        self.printer = Printer(self.console)

    async def run(self, query: str) -> None:
        trace_id = gen_trace_id()
        with trace("Research trace", trace_id=trace_id):
            self.printer.update_item(
                "trace_id",
                f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}",
                is_done=True,
                hide_checkmark=True,
            )

            self.printer.update_item(
                "starting",
                "Starting research...",
                is_done=True,
                hide_checkmark=True,
            )
            search_plan = await self._plan_searches(query)
            search_results = await self._perform_searches(search_plan)
            report = await self._write_report(query, search_results)

            final_report = f"Report summary\n\n{report.short_summary}"
            self.printer.update_item("final_report", final_report, is_done=True)

            self.printer.end()

        print("\n\n=====REPORT=====\n\n")
        print(f"Report: {report.markdown_report}")
        print("\n\n=====FOLLOW UP QUESTIONS=====\n\n")
        unique_questions = []
        seen = set()
        
        for question in report.follow_up_questions:
            if question not in seen:
                unique_questions.append(question)
                seen.add(question)
        
        for i, question in enumerate(unique_questions, 1):
            print(f"{i}. {question}")

    async def _plan_searches(self, query: str) -> WebSearchPlan:
        self.printer.update_item("planning", "Planning searches...")
        result = await Runner.run(
            planner_agent,
            f"Query: {query}",
        )
        self.printer.update_item(
            "planning",
            f"Will perform {len(result.final_output.searches)} searches",
            is_done=True,
        )
        return result.final_output_as(WebSearchPlan)

    async def _perform_searches(self, search_plan: WebSearchPlan) -> list[str]:
        with custom_span("Search the web"):
            self.printer.update_item("searching", "Searching...")
            num_completed = 0
            max_concurrent = 5
            results = []
            
            for i in range(0, len(search_plan.searches), max_concurrent):
                batch = search_plan.searches[i:i+max_concurrent]
                tasks = [asyncio.create_task(self._search(item)) for item in batch]
                
                for task in asyncio.as_completed(tasks):
                    try:
                        result = await task
                        if result is not None:
                            results.append(result)
                    except Exception as e:
                        print(f"Search error: {e}")
                        
                    num_completed += 1
                    self.printer.update_item(
                        "searching", f"Searching... {num_completed}/{len(search_plan.searches)} completed"
                    )
            
            self.printer.mark_item_done("searching")
            return results

    async def _search(self, item: WebSearchItem) -> str | None:
        input = f"Search term: {item.query}\nReason for searching: {item.reason}"
        try:
            result = await Runner.run(
                search_agent,
                input,
            )
            return str(result.final_output)
        except Exception as e:
            print(f"Error searching for '{item.query}': {e}")
            return None

    async def _write_report(self, query: str, search_results: list[str]) -> ReportData:
        self.printer.update_item("writing", "Thinking about report...")
        input = f"Original query: {query}\nSummarized search results: {search_results}"
        
        result = Runner.run_streamed(
            writer_agent,
            input,
        )
        
        update_messages = [
            "Thinking about report...",
            "Planning report structure...",
            "Writing outline...",
            "Creating sections...",
            "Cleaning up formatting...",
            "Finalizing report...",
            "Finishing report...",
        ]

        last_update = time.time()
        next_message = 0
        
        async for event in result.stream_events():
            if time.time() - last_update > 5 and next_message < len(update_messages):
                self.printer.update_item("writing", update_messages[next_message])
                next_message += 1
                last_update = time.time()

        self.printer.mark_item_done("writing")
        return result.final_output_as(ReportData)

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Convert the above flow into a flowchart style image (software of your choosing, but if you're not sure which to use try [Excallidraw](https://excalidraw.com/)) that outlines how the different Agents interact with each other.
#
# > HINT: Cursor's AI (CMD+L or CTRL+L on Windows) would be a helpful way to get a basic diagram that you can add more detail to!

# %%
# Display the research bot flowchart
print("OpenAI Agents SDK Research Bot Flowchart")
print("=" * 50)

flowchart = """
User Query
    │
    ▼
┌─────────────────┐
│  Planner Agent  │
│  (GPT-4.1)     │
│                 │
│ • Analyzes query│
│ • Generates     │
│   5-20 search   │
│   terms         │
│ • Outputs:      │
│   WebSearchPlan │
└─────────────────┘
    │
    ▼
┌─────────────────┐
│  Search Agent   │
│  (GPT-4.1)     │
│                 │
│ • Uses          │
│   WebSearchTool │
│ • Performs      │
│   web searches  │
│ • Outputs:      │
│   Concise       │
│   summaries     │
└─────────────────┘
    │
    ▼
┌─────────────────┐
│  Writer Agent   │
│  (o3-mini)     │
│                 │
│ • Synthesizes   │
│   all results   │
│ • Creates       │
│   comprehensive │
│   report        │
│ • Outputs:      │
│   ReportData    │
└─────────────────┘
    │
    ▼
┌─────────────────┐
│  Final Output   │
│                 │
│ • Markdown      │
│   report        │
│   (5-10 pages) │
│ • Follow-up     │
│   questions     │
│   (5 unique)    │
└─────────────────┘
"""

print(flowchart)
print("\nData Flow:")
print("User Query → WebSearchPlan → Search Results → ReportData → Final Report")
print("\nKey Features:")
print("• Structured outputs ensure reliable data flow")
print("• WebSearchTool enables real web searches") 
print("• Progress tracking with Printer class")
print("• Error handling for failed searches")
print("• Trace IDs for debugging")
print("• Streaming updates during report generation")
# Out:
# OpenAI Agents SDK Research Bot Flowchart
# ==================================================
#
# User Query
#     │
#     ▼
# ┌─────────────────┐
# │  Planner Agent  │
# │  (GPT-4.1)     │
# │                 │
# │ • Analyzes query│
# │ • Generates     │
# │   5-20 search   │
# │   terms         │
# │ • Outputs:      │
# │   WebSearchPlan │
# └─────────────────┘
#     │
#     ▼
# ┌─────────────────┐
# │  Search Agent   │
# │  (GPT-4.1)     │
# │                 │
# │ • Uses          │
# │   WebSearchTool │
# │ • Performs      │
# │   web searches  │
# │ • Outputs:      │
# │   Concise       │
# │   summaries     │
# └─────────────────┘
#     │
#     ▼
# ┌─────────────────┐
# │  Writer Agent   │
# │  (o3-mini)     │
# │                 │
# │ • Synthesizes   │
# │   all results   │
# │ • Creates       │
# │   comprehensive │
# │   report        │
# │ • Outputs:      │
# │   ReportData    │
# └─────────────────┘
#     │
#     ▼
# ┌─────────────────┐
# │  Final Output   │
# │                 │
# │ • Markdown      │
# │   report        │
# │   (5-10 pages) │
# │ • Follow-up     │
# │   questions     │
# │   (5 unique)    │
# └─────────────────┘
#
#
# Data Flow:
# User Query → WebSearchPlan → Search Results → ReportData → Final Report
#
# Key Features:
# • Structured outputs ensure reliable data flow
# • WebSearchTool enables real web searches
# • Progress tracking with Printer class
# • Error handling for failed searches
# • Trace IDs for debugging
# • Streaming updates during report generation

# %% [markdown]
# ## Task 5: Running Our Agent
#
# Now let's run our agent! The main function below will prompt the user for a research topic, then pass that query to our ResearchManager to handle the entire research process. The ResearchManager will:
#
# 1. Break down the query into search items
# 2. Search for information on each item
# 3. Write a comprehensive report based on the search results
#
# Let's see it in action!

# %%
async def main() -> None:
    query = input("What would you like to research? ")
    await ResearchManager().run(query)

# %%
asyncio.run(main())
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# =====REPORT=====
#
#
# Report: # Comprehensive Research Report on Undervalued Tech Stocks Under $50
#
# This report provides an in-depth analysis of five undervalued technology stocks trading under $50 with strong fundamentals. In a market where price does not always tell the full story, a combination of fundamental strength and growth potential can reveal hidden gems. The stocks analyzed in this study are Opera Limited (OPRA), CleanSpark Inc. (CLSK), CSP Inc. (CSPI), Ideal Power Inc. (IPWR), and Airship AI Holdings, Inc. (AISP). Each is assessed based on fundamental metrics, technical indicators, market positioning, and inherent growth catalysts.
#
# ---
#
# ## **1. Executive Summary**
#
# This report aims to identify and evaluate five technology companies that appear undervalued based on key financial metrics and robust growth prospects. The core investment thesis is driven by the following observations:
#
# - *Underpriced Shares*: All selected stocks are trading under $50, reducing entry barriers for both institutional and retail investors.
# - *Strong Fundamentals*: Each company exhibits solid balance sheets, attractive valuation multiples, and positive revenue or earnings growth trends.
# - *Strategic Positioning*: These firms are operating in sectors with strong growth drivers such as AI, renewable energy enhancements, innovative web services, and cybersecurity.
# - *Growth Catalysts*: Specific corporate developments, strategic contracts, and upcoming technological innovations present significant upside potential.
#
# > **Key Insight:** "Investing in undervalued tech stocks can offer attractive risk/reward profiles when one digs deeper into the fundamental and market dynamics that are not immediately obvious from the price alone."
#
# ---
#
# ## **2. Research Methodology**
#
# ### **2.1 Stock Selection Criteria**
#
# The stock selection process was rigorous and centered on several key quantitative and qualitative criteria:
#
# 1. **Price Range:** Only stocks trading under $50 were considered, ensuring that the companies are accessible and potentially undervalued relative to their earnings and growth potential.
#
# 2. **Valuation Multiples:** Stocks with lower Price-to-Earnings (P/E) and Price-to-Book (P/B) ratios compared to industry averages were prioritized.
#
# 3. **Financial Health:** A robust balance sheet, low debt-to-equity ratio, and positive cash flow were mandatory indicators of strong fundamentals.
#
# 4. **Revenue & Earnings Growth:** A record of steady or accelerating growth in revenues and earnings was essential, indicating a scalable business model.
#
# 5. **Market Position & Catalysts:** Companies with strong market positioning in niche segments of the technology sector, supported by strategic partnerships or technological breakthroughs, were selected.
#
# ### **2.2 Data Sources & Screening Process**
#
# - **Screening Tools:** Several screening platforms such as Yahoo Finance, Finviz, and Nasdaq were used to gather preliminary data on key metrics.
# - **Analyst Reports:** Insights were corroborated with recent analyst opinions, earnings reports, and industry news to validate growth prospects.
# - **Technical Analysis:** Key technical indicators including moving averages, relative strength index (RSI), and volume trends were extracted to time entry and exit points.
# - **Qualitative Research:** News articles, company announcements, and regulatory releases were reviewed to capture any additional qualitative catalysts.
#
# > **Key Insight:** "A comprehensive research approach that combines both quantitative screenings and qualitative insights often reveals promising opportunities that might be overlooked by a superficial analysis."
#
# ---
#
# ## **3. Stock Analysis**
#
# This section details the individual analysis of the five selected stocks, summarizing key financial metrics, providing an investment thesis, and outlining risk factors along with recommended price targets.
#
# ### **3.1 Opera Limited (OPRA)**
#
# - **Ticker Symbol & Company Name:** OPRA - Opera Limited
# - **Current Price & Market Cap:** Approximately $47 per share; Market capitalization reflects a mid-cap profile in the tech space.
#
# - **Key Financial Metrics:**
#   - **P/E Ratio:** ~20 (indicative of moderate earnings relative to share price)
#   - **P/B Ratio:** ~2.5
#   - **Dividend Yield:** Approximately 4%, highlighting a modest income element
#   - **Debt/Equity Ratio:** Low, underscoring a strong balance sheet
#
# - **Investment Thesis:**
#   Opera Limited is recognized as a pioneer in web browsing technology with its proprietary platform now integrating advanced AI capabilities. The company’s recent push towards AI-driven features has broadened its market appeal, especially in regions where alternative browsers struggle to gain market share. Its balanced mix of growth and dividend yield adds defensive value for investors.
#
# - **Risk Factors & Mitigation:**
#   - **Competition:** Faces stiff competition from dominant players like Google and Microsoft.
#     *Mitigation:* Continuous innovation in AI and strategic partnerships can sustain its niche appeal.
#   - **Market Penetration:** As it transitions into new verticals, there exists a risk of slow market adoption.
#     *Mitigation:* Diversification in revenue streams (advertising, subscription services) can help offset slower growth in any single segment.
#
# - **Price Targets & Entry/Exit Points:**
#   - *Short-Term Entry:* Consider an entry point around $45-47, with technical support near moving averages.
#   - *Long-Term Price Target:* Analysts foresee a potential upswing to $60 as AI integration scales and market share improves.
#
# ### **3.2 CleanSpark Inc. (CLSK)**
#
# - **Ticker Symbol & Company Name:** CLSK - CleanSpark Inc.
# - **Current Price & Market Cap:** Trading at roughly $18 per share; it falls within the small-to-mid cap segment.
#
# - **Key Financial Metrics:**
#   - **P/E Ratio:** Approximately 10 (reflecting relative undervaluation)
#   - **P/B Ratio:** ~1.2, suggesting minimal overvaluation in terms of book value
#   - **Revenue Growth:** Robust, driven by strategic acquisitions and scaling of low-carbon cryptocurrency mining operations
#   - **Cash Flow:** Indicators suggest positive operational cash flows post recent facility acquisitions
#
# - **Investment Thesis:**
#   CleanSpark is strategically positioned in the evolving cryptocurrency mining space, with an emphasis on renewable and low-carbon operations. Its recent acquisitions have doubled its operational capacity, and its cost structure remains efficient compared to peers. As the market matures and digital assets become increasingly mainstream, CleanSpark stands to benefit from both operational scale and improved margins.
#
# - **Risk Factors & Mitigation:**
#   - **Regulatory Uncertainty:** The crypto space is heavily influenced by regulatory changes.
#     *Mitigation:* A diversified energy approach and compliance initiatives can reduce regulatory exposure.
#   - **Market Volatility:** Crypto prices are notoriously volatile, affecting revenue visibility.
#     *Mitigation:* Focus on long-term operational metrics rather than short-term market fluctuations.
#
# - **Price Targets & Entry/Exit Points:**
#   - *Entry Strategy:* Accumulate at current levels near $18, especially useful during market corrections.
#   - *Long-Term Target:* Could reach above $25 if crypto adoption accelerates and renewable integration benefits are realized.
#
# ### **3.3 CSP Inc. (CSPI)**
#
# - **Ticker Symbol & Company Name:** CSPI - CSP Inc.
# - **Current Price & Market Cap:** Currently around $42 per share, positioning it in the lower mid-cap bracket.
#
# - **Key Financial Metrics:**
#   - **P/E Ratio:** Approximately 18, aligning it well below many industry peers
#   - **P/B Ratio:** Around 2.0, indicating that the stock is reasonably valued relative to its net assets
#   - **Revenue Growth:** Demonstrating a steady annual increase (estimated around 10-12% YoY)
#   - **Operating Margin:** Improving margins as the company realizes economies of scale in its defense and cybersecurity segments
#
# - **Investment Thesis:**
#   CSP Inc. specializes in providing technology-driven solutions within defense, cybersecurity, and IT services. Their recent announcement of a stock split and strategic contract wins signal growing investor confidence. The company’s blended offering of digital security and IT support is well-positioned against increasing cybersecurity threats and technological advancements in the defense sector.
#
# - **Risk Factors & Mitigation:**
#   - **Sector Cyclicality:** Defense and cybersecurity budgets can be subject to fluctuations in governmental spending cycles.
#     *Mitigation:* Long-term contracts and diversified revenue streams can help smoothen cyclic effects.
#   - **Technology Evolution:** Rapid advancements in tech require continual R&D investments.
#     *Mitigation:* The company’s consistent reinvestment in R&D and strategic partnerships mitigates the risk of obsolescence.
#
# - **Price Targets & Entry/Exit Points:**
#   - *Entry Point:* Buy around current levels ($40-42) if further technical support is confirmed and market sentiment remains positive.
#   - *Target Price:* Analysts forecast an upward adjustment to $55 as digital transformation initiatives and defense budgets increase.
#
# ### **3.4 Ideal Power Inc. (IPWR)**
#
# - **Ticker Symbol & Company Name:** IPWR - Ideal Power Inc.
# - **Current Price & Market Cap:** Trading at approximately $15 per share; considered a micro-cap stock with high future potential.
#
# - **Key Financial Metrics:**
#   - **P/E Ratio:** Not applicable as the company is currently investing in growth over profit (reinvesting revenues into R&D and market expansion).
#   - **P/B Ratio:** Around 1.0, suggesting that its market price is closely aligned with its book value
#   - **Revenue Growth:** Recently recorded its first commercial revenue in 2023 with projections for rapid future growth due to its innovative technology
#   - **Margin Profile:** Currently operating with narrow margins; however, gross margins are expected to widen as production scales and costs decline
#
# - **Investment Thesis:**
#   Ideal Power is pioneering bidirectional semiconductor power switches aimed at electrification in vehicles and renewable energy technologies. Its breakthrough product has demonstrated technical feasibility and early market traction, positioning it to capture a significant share of sectors transitioning to cleaner and more efficient power systems. While early in its revenue journey, the technological edge and growing market demand may translate into substantial long-term gains.
#
# - **Risk Factors & Mitigation:**
#   - **Early Stage Risks:** Being in the early stage of commercial revenue, the company risks volatility in earnings.
#     *Mitigation:* A clear roadmap for scaling production and securing long-term supply contracts can reduce these risks.
#   - **Competitive Landscape:** The semiconductor market is highly competitive with established players.
#     *Mitigation:* Focus on niche, high-efficiency power solutions and strategic IP protection can provide a competitive moat.
#
# - **Price Targets & Entry/Exit Points:**
#   - *Entry Strategy:* Accumulate positions at current levels with a cautious approach, given early-growth stage volatility.
#   - *Long-Term Price Target:* Could target a price of $25+ as production scales and margins improve, subject to successful market penetration.
#
# ### **3.5 Airship AI Holdings, Inc. (AISP)**
#
# - **Ticker Symbol & Company Name:** AISP - Airship AI Holdings, Inc.
# - **Current Price & Market Cap:** Trading close to $30 per share; relatively well-capitalized in the small-to-mid cap space.
#
# - **Key Financial Metrics:**
#   - **P/E Ratio:** Approximately 22, reflecting expectations of future earnings growth
#   - **P/B Ratio:** Around 3.0, tied to the company’s significant investments in intellectual property
#   - **Revenue Growth:** Exhibiting strong YoY revenue increases (estimated growth around 20% driven by contract wins and expansion efforts)
#   - **Contract Wins & Backlog:** Recently secured a high-profile contract with a U.S. Department of Justice agency, reinforcing its product-market fit
#
# - **Investment Thesis:**
#   Airship AI Holdings specializes in AI-driven video analysis software emphasizing security and law enforcement solutions. Its recent contract with a major U.S. agency underscores its capability to deliver mission-critical technology solutions. With cyber and physical security concerns rising globally, Airship is uniquely positioned to benefit from increased government and commercial spending on advanced video analytics and AI-powered surveillance technologies.
#
# - **Risk Factors & Mitigation:**
#   - **Sector Regulation:** Operating in security and surveillance, subject to strict regulatory environments.
#     *Mitigation:* Ongoing compliance efforts and diversified contract wins help lower regulatory risks.
#   - **R&D Intensity:** High investment in product development may pressure short-term profitability.
#     *Mitigation:* Long-term contract agreements and a growing client base are expected to balance out initial R&D expenditures.
#
# - **Price Targets & Entry/Exit Points:**
#   - *Entry Point:* A buy point in the $28-30 range is recommended if technical indicators remain bullish.
#   - *Target Price:* With successful contract execution and revenue growth, a target of $40+ is projected over the medium term.
#
# ---
#
# ## **4. Comparative Analysis**
#
# Below is a detailed table comparing the key metrics of the five selected stocks:
#
# | Ticker | Price  | P/E   | P/B  | Growth (YoY) | Risk Level  | Rating |
# |--------|--------|-------|------|--------------|-------------|--------|
# | OPRA   | ~$47   | 20    | 2.5  | ~15%         | Low         | Buy    |
# | CLSK   | ~$18   | 10    | 1.2  | ~25%         | Moderate    | Buy    |
# | CSPI   | ~$42   | 18    | 2.0  | ~12%         | Moderate    | Buy    |
# | IPWR   | ~$15   | N/A   | 1.0  | ~30%*        | High        | Hold   |
# | AISP   | ~$30   | 22    | 3.0  | ~20%         | Moderate    | Buy    |
#
# *Note: For Ideal Power Inc. (IPWR), the absence of a P/E ratio reflects its current reinvestment stage in pursuit of long-term growth.
#
# ---
#
# ## **5. Investment Strategy**
#
# A well-rounded investment strategy for these undervalued tech stocks should consider the following components:
#
# ### **5.1 Portfolio Allocation Recommendations**
#
# - **Diversification:** Distribute capital across stocks with different technology focuses:
#   1. **Opera (OPRA):** Provides exposure to AI-enhanced web services and digital advertising.
#   2. **CleanSpark (CLSK):** Offers a play in renewable technology integration within crypto mining.
#   3. **CSP Inc. (CSPI):** Balances the portfolio with defense, cybersecurity, and IT services exposure.
#   4. **Ideal Power (IPWR):** A high-growth, early-stage investment in semiconductor power technology.
#   5. **Airship AI (AISP):** Capitalizes on the surge in AI and video analytics for security applications.
#
# - **Position Sizing:** Allocate a larger percentage (25%-30%) to stocks with lower volatility and proven fundamentals (OPRA, CLSK, CSPI) while assigning a smaller weight (15%-20%) to higher-risk, high-growth names (IPWR and AISP).
#
# ### **5.2 Entry Timing and Technical Considerations**
#
# - **Technical Indicators:** Consider using moving averages, RSI levels, and support/resistance patterns to time entries. For example, a dip toward a 50-day moving average or oversold signals on the RSI can be ideal entry points.
#
# - **Staggered Entry:** For volatile stocks like Ideal Power (IPWR), a staggered entry strategy (dollar-cost averaging) can help mitigate short-term price fluctuations.
#
# ### **5.3 Risk Management Guidelines**
#
# - **Stop Losses & Position Limits:** Using stop-loss orders to safeguard against unexpected downturns is recommended, especially in the higher-risk segments.
#
# - **Regular Reviews:** Periodically re-assessing each holding in light of new earnings data, industry trends, and technical signals is essential to ensure the portfolio stays aligned with growth objectives.
#
# > **Key Insight:** "A disciplined entry and exit strategy combined with position sizing is fundamental to managing risks in a volatile tech market."
#
# ---
#
# ## **6. Market Outlook**
#
# ### **6.1 Sector Trends and Catalysts**
#
# - **AI and Machine Learning:** As numerous tech firms integrate AI, companies like Opera Limited and Airship AI stand to benefit from enhanced digital tools and security systems.
#
# - **Renewable Energy & Sustainability:** CleanSpark’s focus on low-carbon operations resonates with the broader market shift to sustainable energy practices, a trend likely to accelerate in coming years.
#
# - **Cybersecurity & Defense:** CSP Inc. is well-positioned as governments and corporations expand their cybersecurity budgets in response to evolving digital threats.
#
# - **Semiconductors & Power Technologies:** Ideal Power’s innovative solutions are timely, with the global push for electrification and advanced power management solutions gaining momentum.
#
# ### **6.2 Economic Factors**
#
# - **Interest Rates and Inflation:** Generally, tech stocks benefit from a low interest rate environment that encourages growth funding. However, rising interest rates could put pressure on valuations, emphasizing the need for strong fundamentals.
#
# - **Global Trade Dynamics:** Geopolitical tensions and supply chain disruptions can impact tech companies. Diversified operations and strong domestic markets (as seen with CSP Inc.) can cushion against such shocks.
#
# > **Key Insight:** "The evolving economic landscape coupled with the rapid advancement of technology creates both challenges and significant opportunities for innovative tech companies."
#
# ---
#
# ## **7. Risk Assessment**
#
# ### **7.1 Market Risks**
#
# - **Economic Cyclicality:** Economic downturns and changes in consumer demand can affect tech spending. Broad market corrections might trigger short-term declines even in fundamentally sound companies.
# - **Regulatory Environment:** Changes in regulatory frameworks, particularly in areas like data privacy, cryptocurrency, and cybersecurity, might impose additional costs or limit operational flexibility.
#
# ### **7.2 Company-Specific Risks**
#
# - **Competition:** The tech industry is fiercely competitive. Giants with significant R&D budgets might outpace smaller firms, even if they are currently undervalued.
# - **Execution Risks:** Especially for early-stage companies like Ideal Power Inc., execution risks related to commercializing new technology can lead to volatility in growth and earnings.
# - **Technological Obsolescence:** Rapid technological changes may render current products or services obsolete if companies fail to innovate continuously.
#
# ### **7.3 Mitigation Strategies**
#
# - **Diversification:** Investing across multiple segments within the tech sector can mitigate the impact of a downturn in any one area.
# - **Hedging:** Using options or other hedging strategies can protect gains during market corrections.
# - **Active Monitoring:** Regular reviews, combined with a responsive trading strategy, help adjust holdings quickly in response to market changes.
#
# > **Key Insight:** "While the tech sector offers high-growth opportunities, a keen awareness of both macroeconomic and company-specific risks is essential for preserving capital and ensuring long-term success."
#
# ---
#
# ## **Conclusion**
#
# The analysis of Opera Limited (OPRA), CleanSpark Inc. (CLSK), CSP Inc. (CSPI), Ideal Power Inc. (IPWR), and Airship AI Holdings, Inc. (AISP) demonstrates that these stocks, trading under $50, offer compelling opportunities for investors seeking undervalued assets with strong fundamental profiles. Each stock brings forth a unique combination of innovative technology, growth potential, and reasonable valuation metrics.
#
# Investors are encouraged to monitor these picks closely, considering both the long-term industry trends and short-term technical signals to optimize entry and exit points. Additionally, the outlined risk management strategies and diversification frameworks provide a robust plan to harness the upside potential while mitigating inherent risks.
#
# Ultimately, the balanced approach outlined in this report underscores the importance of a dual focus on both fundamental value and technical timing in capturing gains from undervalued tech opportunities.
#
# ---
#
# *End of Report*
#
#
# =====FOLLOW UP QUESTIONS=====
#
#
# 1. What additional technical indicators (e.g., RSI, MACD) could be used to refine entry and exit strategies for these stocks?
# 2. How might upcoming regulatory changes or geopolitical events impact the performance of these tech stocks under $50?
# 3. What are the detailed R&D and innovation roadmaps for companies like Ideal Power Inc. and Airship AI Holdings that could affect their long-term market positions?
# 4. How do the current market valuations of these stocks compare with historical averages in their respective sub-sectors?
# 5. What alternative screening criteria could be employed to identify similar undervalued tech stocks in emerging international markets?

# %% [markdown]
# ---
#
# ## Sample Report in Markdown
#
# ---

# %% [markdown]
# # OpenAI Agents SDK: A Comprehensive Report
#
# *Published: October 2023*
#
# ## Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Core Concepts and Key Features](#core-concepts-and-key-features)
# 3. [Architecture and Developer Experience](#architecture-and-developer-experience)
# 4. [Comparative Analysis with Alternative Frameworks](#comparative-analysis-with-alternative-frameworks)
# 5. [Integrations and Real-World Applications](#integrations-and-real-world-applications)
# 6. [Troubleshooting, Observability, and Debugging](#troubleshooting-observability-and-debugging)
# 7. [Community Impact and Future Directions](#community-impact-and-future-directions)
# 8. [Conclusion](#conclusion)
#
# ---
#
# ## Introduction
#
# In March 2025, OpenAI released the Agents SDK, a groundbreaking, open-source framework aimed at simplifying the development of autonomous AI agents capable of performing intricate tasks with minimal human intervention. Designed with a Python-first approach, the SDK offers a minimal set of abstractions, yet provides all the necessary components to build, debug, and optimize multi-agent workflows. The release marked a significant milestone for developers who seek to integrate large language models (LLMs) with advanced task delegation mechanisms, enabling next-generation automation in various industries.
#
# The primary goal of the OpenAI Agents SDK is to streamline the creation of agentic applications by offering core primitives such as *agents*, *handoffs*, and *guardrails*. These primitives are essential for orchestrating autonomous AI systems that perform key functions such as web search, file operations, and even actions on a computer. This report delves into the SDK's features, its operational architecture, integration capabilities, and how it compares to other frameworks in the rapidly evolving landscape of AI development tools.
#
# ## Core Concepts and Key Features
#
# ### Agents
#
# At the heart of the SDK are **agents**—intelligent entities that encapsulate a specific set of instructions and tools. Each agent is built on top of a large language model and can be customized with its own personality, domain expertise, and operational directives. For example, a "Math Tutor" agent could be designed to solve math problems by explaining each step clearly.
#
# **Key elements of an agent include:**
#
# - **Instructions:** Specific guidelines that shape the agent's responses and behavior in the context of its designated role.
# - **Tools:** Predefined or dynamically integrated tools that the agent can leverage to access external resources (e.g., web search or file search functionalities).
#
# ### Handoffs
#
# A unique feature introduced by the SDK is the concept of **handoffs**. Handoffs allow agents to delegate tasks to one another based on expertise and contextual needs. This orchestration paves the way for sophisticated workflows where multiple agents work in tandem, each contributing its specialized capabilities to complete a complex task.
#
# ### Guardrails
#
# Safety and reliability remain a cornerstone in AI development, and the SDK introduces **guardrails** as a means of controlling input and output validation. Guardrails help ensure that agents operate within defined safety parameters, preventing unintended actions and mitigating risks associated with autonomous decision-making.
#
# ### Built-in Debugging and Observability
#
# The development process is further enhanced by built-in **tracing and visualization tools**. These tools offer real-time insights into agent interactions, tool invocations, and decision-making pathways, thereby making debugging and optimization more accessible and systematic. The tracing functionality is a vital feature for developers looking to fine-tune agent performance in production environments.
#
# ## Architecture and Developer Experience
#
# ### Python-First Approach
#
# The SDK is inherently Python-based, making it highly accessible to the vast community of Python developers. By leveraging existing language features without introducing excessive abstractions, the SDK provides both simplicity and power. The installation is straightforward:
#
# ```bash
# mkdir my_project
# cd my_project
# python -m venv .venv
# source .venv/bin/activate
# pip install openai-agents
# ```
#
# Once installed, developers can create and configure agents with minimal boilerplate code. The emphasis on a minimal learning curve has been a significant point of praise among early adopters.
#
# ### Developer Tools and Tutorials
#
# In addition to comprehensive official documentation available on OpenAI’s GitHub pages, the community has contributed numerous tutorials and code examples. Video tutorials by experts such as Sam Witteveen and James Briggs provide hands-on demonstrations, ranging from simple agent creation to more sophisticated scenarios involving parallel execution and advanced tool integrations.
#
# ### Use of Python's Ecosystem
#
# The integration with Python’s ecosystem means that developers can immediately apply a range of established libraries and frameworks. For instance, utilizing Pydantic for input validation in guardrails or leveraging visualization libraries to display agent workflows are examples of how the SDK embraces the strengths of Python.
#
# ## Comparative Analysis with Alternative Frameworks
#
# While the OpenAI Agents SDK has received acclaim for its simplicity and robust integration with OpenAI’s ecosystem, other frameworks such as LangGraph, CrewAI, and AutoGen have emerged as viable alternatives. Here’s how they compare:
#
# - **LangGraph:** Known for its graph-based architecture, LangGraph is ideal for handling complex and cyclical workflows that require sophisticated state management. However, it comes with a steeper learning curve, making it less accessible for projects that require quick prototyping.
#
# - **CrewAI:** Emphasizing a role-based multi-agent system, CrewAI excels in scenarios where collaboration among agents is critical. Its design promotes clear segregation of duties among different agents, which can be beneficial in customer service or large-scale business automation.
#
# - **AutoGen:** This framework supports flexible conversation patterns and diverse agent interactions, particularly useful in applications where adaptive dialogue is essential. Nevertheless, AutoGen may introduce additional overhead when managing state and coordinating multiple agents.
#
# In contrast, the OpenAI Agents SDK strikes an effective balance by offering a lightweight yet powerful toolset geared towards production readiness. Its strengths lie in its minimal abstractions, ease of integration with various tools (like web search and file search), and built-in observability features that are crucial for debugging and tracing agent interactions.
#
# ## Integrations and Real-World Applications
#
# ### Diverse Integrations
#
# The real power of the OpenAI Agents SDK surfaces when it is integrated with other systems and platforms. Notable integrations include:
#
# - **Box Integration:** Enhancing enterprise content management, Box has adopted the SDK to enable secure AI-powered data processing. This integration allows agents to reliably access and interpret proprietary data.
#
# - **Coinbase AgentKit:** With financial capabilities in mind, Coinbase introduced AgentKit, leveraging the SDK to incorporate financial operations and risk analysis directly into AI agents.
#
# - **Milvus and Ollama:** These integrations allow the SDK to handle high-performance data queries and run agents on local infrastructure respectively, ensuring both speed and privacy.
#
# ### Real-World Applications
#
# The versatility of the SDK lends itself to a multitude of applications:
#
# - **Customer Support:** Automated agents can be built to handle customer inquiries, providing faster and more accurate responses while reducing workload on human agents.
#
# - **Content Generation:** In marketing and media, agents can generate high-quality articles, detailed reports, and even code reviews with built-in content guidelines.
#
# - **Financial Analysis:** Specialized agents capable of real-time data fetching and market analysis can generate actionable insights for investors and analysts.
#
# - **Health and Wellness:** Custom agents can handle tasks such as appointment scheduling, patient record management, and even provide personalized fitness and dietary recommendations.
#
# - **Educational Tools:** Intelligent tutoring agents can assist students by providing personalized learning experiences and instant feedback on assignments.
#
# These applications underscore the SDK’s transformative potential across various industries, driving the trend towards increased automation and efficiency.
#
# ## Troubleshooting, Observability, and Debugging
#
# ### Common Issues and Solutions
#
# As with any cutting-edge technology, developers working with the OpenAI Agents SDK have encountered challenges:
#
# - **API Key Management:** Authentication errors due to missing or invalid API keys are common. The solution involves ensuring that the `OPENAI_API_KEY` environment variable is correctly set or programmatically configured using OpenAI’s helper functions.
#
# - **Rate Limitations:** Rate limits, an intrinsic challenge with API-based services, require developers to monitor dashboard usage and implement retry strategies with exponential backoff.
#
# - **Response Delays:** Network latency and high server loads can result in unexpected delays. Developers are advised to check network settings, adhere to best practices in setting request timeouts, and monitor OpenAI’s service status.
#
# ### Built-In Tracing Capabilities
#
# The SDK provides robust tracing tools that log agent inputs, outputs, tool interactions, and error messages. This level of observability is crucial for debugging complex workflows and allows developers to visualize the agent’s decision-making process in real time. By configuring a `TracingConfig` object, developers can capture detailed insights and identify performance bottlenecks.
#
# ### Best Practices
#
# - **Prompt Engineering:** Refine prompts to reduce ambiguity and minimize unexpected outputs.
# - **Layered Validation:** Use guardrails extensively to ensure inputs and outputs are verified at multiple layers.
# - **Modular Design:** Break complex tasks into smaller, more manageable components using handoffs to delegate tasks appropriately.
#
# ## Community Impact and Future Directions
#
# ### Developer and Enterprise Adoption
#
# The release of the OpenAI Agents SDK has been met with enthusiasm within the developer community. Its ease of use, combined with comprehensive documentation and community-driven resources (such as tutorials on Class Central and DataCamp), has accelerated its adoption across educational, enterprise, and research sectors.
#
# Several leading organizations, including Box and Coinbase, have integrated the SDK into their workflows, demonstrating its capability to drive real-world business solutions. The open-source nature of the SDK, licensed under the MIT License, further encourages widespread industrial collaboration and innovation.
#
# ### Future Prospects
#
# Looking forward, OpenAI plans to extend the SDK’s support beyond Python, potentially embracing other programming languages like JavaScript. Additionally, future updates are anticipated to expand tool integrations, further enhance safety mechanisms, and streamline the development of multi-agent ecosystems. Planned deprecations of older APIs, such as the Assistants API in favor of the more unified Responses API, underline the SDK’s evolving roadmap aimed at future-proofing agentic applications.
#
# ## Conclusion
#
# The OpenAI Agents SDK represents a significant step forward in the field of AI development. Its lightweight, Python-first framework facilitates the creation of autonomous agents that can handle a wide array of tasks—from simple inquiries to complex multi-agent systems. The SDK’s robust integration capabilities, combined with its focus on safety and observability, make it an ideal choice for both developers and enterprises seeking to build reliable, scalable agentic applications.
#
# In summary, the SDK not only lowers the barrier to entry for developing sophisticated AI applications but also sets the stage for further innovations as the ecosystem evolves. It is poised to become a standard toolkit for the next generation of AI-driven technologies, empowering users across sectors to achieve greater efficiency and creativity in task automation.
#
# ---
#
# *For further reading, developers are encouraged to visit the official OpenAI documentation, join the community forums, and explore real-world use cases to deepen their understanding of this transformative tool.*
